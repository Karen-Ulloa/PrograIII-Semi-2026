# %% [markdown]
# <a href="https://colab.research.google.com/github/Karen-Ulloa/PrograIII-Semi-2026/blob/Parcial-I/PARCIAL_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **# PARCIAL I**

# %% [markdown]
#  1 IMPUESTO DE LAS ACTIVIDADES ECONOMICAS

# %%
"""
Calculo del IMPUESTO A LAS ACTIVIDADES ECONOMICAS
--------------------------------------------------
El usuario introduce el monto de la actividad economica y el programa
determina en que tramo (segun la tabla) cae ese monto, para luego
calcular el impuesto con la formula:

    Impuesto = PRECIO + ( (Monto - DESDE) * ADICIONAL / 1000 )

("ADICIONAL" se aplica al millar sobre el exceso del limite inferior
del tramo, tal como se maneja en las tarifas municipales de El Salvador).
"""

# Tabla de tramos segun la Tarifa de Arbitrios Municipal de El Salvador

TABLA_IMPUESTOS = [
    (1,  0.01,       500.00,      1.5,  0.0),
    (2,  500.01,     1000.00,     1.5,  3.0),
    (3,  1000.01,    2000.00,     3.0,  3.0),
    (4,  2000.01,    3000.00,     6.0,  3.0),
    (5,  3000.01,    6000.00,     9.0,  2.0),
    (6,  8000.01,    18000.00,    15.0, 2.0),
    (7,  18000.01,   30000.00,    39.0, 2.0),
    (8,  30000.01,   60000.00,    63.0, 1.0),
    (9,  60000.01,   100000.00,   93.0, 0.8),
    (10, 100000.01,  200000.00,   125.0, 0.7),
    (11, 200000.01,  300000.00,   195.0, 0.6),
    (12, 300000.01,  400000.00,   255.0, 0.45),
    (13, 400000.01,  500000.00,   300.0, 0.4),
    (14, 500000.01,  1000000.00,  340.0, 0.30),
    (15, 1000000.01, 99999999.00, 490.0, 0.18),
]


def calcular_impuesto(monto):
    """
    Busca el tramo al que pertenece 'monto' dentro de TABLA_IMPUESTOS
    y calcula el impuesto correspondiente con la formula oficial:

        Impuesto = Precio + ( (Monto - Desde) / 1000 * Adicional )

    Retorna una tupla (numero_tramo, impuesto) o (None, None) si el
    monto no cae en ningun tramo de la tabla.
    """
    for num_tramo, desde, hasta, precio, adicional in TABLA_IMPUESTOS:
        if desde <= monto <= hasta:
            impuesto = precio + ((monto - desde) * adicional / 1000)
            return num_tramo, impuesto
    return None, None


def pedir_monto():
    """Solicita al usuario el monto de la actividad economica y valida la entrada."""
    while True:
        entrada = input("Introduzca el monto de la actividad economica: $")
        try:
            monto = float(entrada)
            if monto <= 0:
                print("El monto debe ser mayor a 0. Intente de nuevo.\n")
                continue
            return monto
        except ValueError:
            print("Entrada invalida. Debe ingresar un numero. Intente de nuevo.\n")


def main():
    print("=" * 55)
    print("   CALCULO DEL IMPUESTO A LAS ACTIVIDADES ECONOMICAS")
    print("=" * 55)

    monto = pedir_monto()
    tramo, impuesto = calcular_impuesto(monto)

    print("\n--- RESULTADO ---")
    print(f"Monto ingresado : ${monto:,.2f}")

    if tramo is not None:
        print(f"Tramo aplicado  : No. {tramo}")
        print(f"Impuesto a pagar: ${impuesto:,.2f}")
    else:
        print("El monto ingresado no se encuentra dentro de ningun tramo")
        print("definido en la tabla (rango valido: $0.01 - $99,999,999.00).")


if __name__ == "__main__":
    main()
# Out:
# ...
#    CALCULO DEL IMPUESTO A LAS ACTIVIDADES ECONOMICAS
# ...
# Introduzca el monto de la actividad economica: $20000
#
# --- RESULTADO ---
# Monto ingresado : $20,000.00
# Tramo aplicado  : No. 7
# Impuesto a pagar: $43.00

# %% [markdown]
# 2 CONVERSOR DE AREA

# %%
"""
CONVERSOR DE AREA (SUPERFICIE)
------------------------------
Convierte entre las unidades de superficie tradicionales de El Salvador:
    a. Pie cuadrado
    b. Vara cuadrada
    c. Yarda cuadrada
    d. Metro cuadrado
    e. Tareas
    f. Manzana
    g. Hectarea

Se usa el METRO CUADRADO (m2) como unidad base: primero se convierte el
valor de entrada a m2 y luego de m2 a la unidad de salida.

Factores de equivalencia a metros cuadrados (fuente: Tabla Oficial de
Conversion de Unidades, El Salvador / vara salvadorena = 0.835905 m):
    1 pie cuadrado  = 0.092903 m2
    1 vara cuadrada = 0.698896 m2
    1 yarda cuadrada = 0.836127 m2
    1 metro cuadrado = 1 m2  (unidad base)
    1 tarea          = 436.81 m2   (1 manzana / 16)
    1 manzana        = 6988.96 m2
    1 hectarea       = 10000 m2
"""

# Diccionario con los factores de conversion de cada unidad a metros cuadrados
FACTORES_A_M2 = {
    "pie cuadrado":    0.092903,
    "vara cuadrada":   0.698896,
    "yarda cuadrada":  0.836127,
    "metro cuadrado":  1.0,
    "tareas":          436.81,
    "manzana":         6988.96,
    "hectarea":        10000.0,
}

# Diccionario que asocia cada opcion del menu con el nombre de la unidad
OPCIONES = {
    "a": "pie cuadrado",
    "b": "vara cuadrada",
    "c": "yarda cuadrada",
    "d": "metro cuadrado",
    "e": "tareas",
    "f": "manzana",
    "g": "hectarea",
}


def convertir_a_m2(valor, unidad_origen):
    """Convierte 'valor' desde 'unidad_origen' a metros cuadrados (m2)."""
    factor = FACTORES_A_M2[unidad_origen]
    return valor * factor


def convertir_desde_m2(valor_m2, unidad_destino):
    """Convierte un valor en metros cuadrados (m2) a 'unidad_destino'."""
    factor = FACTORES_A_M2[unidad_destino]
    return valor_m2 / factor


def convertir(valor, unidad_origen, unidad_destino):
    """
    Funcion principal de conversion: pasa el valor a m2 y de ahi a la
    unidad de destino. Retorna el resultado en la unidad de destino.
    """
    m2 = convertir_a_m2(valor, unidad_origen)
    return convertir_desde_m2(m2, unidad_destino)


def mostrar_menu(mensaje):
    """Imprime el menu de unidades y solicita al usuario que elija una opcion valida."""
    print(mensaje)
    for letra, nombre in OPCIONES.items():
        print(f"  {letra}. {nombre.capitalize()}")

    while True:
        opcion = input("Seleccione una opcion (a-g): ").strip().lower()
        if opcion in OPCIONES:
            return OPCIONES[opcion]
        print("Opcion invalida. Intente de nuevo.\n")


def formatear_numero(numero, decimales=4):
    """
    Da formato a un numero para mostrarlo:
    - Si no tiene parte decimal (ej. 1.0, 100.0), lo muestra como entero (1, 100).
    - Si tiene parte decimal, lo muestra con hasta 'decimales' posiciones,
      quitando ceros sobrantes al final (ej. 1.5000 -> 1.5, 9.2903 -> 9.2903).
    """
    redondeado = round(numero, decimales)
    if redondeado == int(redondeado):
        return f"{int(redondeado):,}"
    texto = f"{redondeado:,.{decimales}f}".rstrip("0").rstrip(".")
    return texto


def pedir_valor():
    """Solicita al usuario el valor numerico a convertir, validando la entrada."""
    while True:
        entrada = input("Introduzca el valor a convertir: ")
        try:
            valor = float(entrada)
            if valor < 0:
                print("El valor no puede ser negativo. Intente de nuevo.\n")
                continue
            return valor
        except ValueError:
            print("Entrada invalida. Debe ingresar un numero. Intente de nuevo.\n")


def main():
    print("=" * 55)
    print("   CONVERSOR DE AREA (SUPERFICIE) - EL SALVADOR")
    print("=" * 55)

    continuar = "s"
    while continuar == "s":
        print()
        unidad_origen = mostrar_menu("\nUnidad DE ORIGEN (la que ya tiene):")
        unidad_destino = mostrar_menu("\nUnidad DE DESTINO (a la que desea convertir):")
        valor = pedir_valor()

        resultado = convertir(valor, unidad_origen, unidad_destino)

        print("\n--- RESULTADO ---")
        print(f"{formatear_numero(valor)} {unidad_origen} = {formatear_numero(resultado)} {unidad_destino}")

        continuar = input("\n¿Desea realizar otra conversion? (s/n): ").strip().lower()

    print("\n¡Gracias por usar el conversor!")


if __name__ == "__main__":
    main()
# Out:
# ...
#    CONVERSOR DE AREA (SUPERFICIE) - EL SALVADOR
# ...
#
#
# Unidad DE ORIGEN (la que ya tiene):
#   a. Pie cuadrado
#   b. Vara cuadrada
#   c. Yarda cuadrada
#   d. Metro cuadrado
#   e. Tareas
#   f. Manzana
#   g. Hectarea
# Seleccione una opcion (a-g): f
#
# Unidad DE DESTINO (a la que desea convertir):
#   a. Pie cuadrado
#   b. Vara cuadrada
#   c. Yarda cuadrada
#   d. Metro cuadrado
#   e. Tareas
#   f. Manzana
#   g. Hectarea
# Seleccione una opcion (a-g): e
# Introduzca el valor a convertir: 1
#
# --- RESULTADO ---
# 1 manzana = 16 tareas
#
# ¿Desea realizar otra conversion? (s/n): s
#
#
# Unidad DE ORIGEN (la que ya tiene):
#   a. Pie cuadrado
#   b. Vara cuadrada
#   c. Yarda cuadrada
#   d. Metro cuadrado
#   e. Tareas
#   f. Manzana
#   g. Hectarea
# Seleccione una opcion (a-g): f
#
# Unidad DE DESTINO (a la que desea convertir):
#   a. Pie cuadrado
#   b. Vara cuadrada
#   c. Yarda cuadrada
#   d. Metro cuadrado
#   e. Tareas
#   f. Manzana
#   g. Hectarea
# ...

# %% [markdown]
# 3. Sistema estadistico
# 4. Sistema Academico usando JSON/diccionarios

# %%
import math
from collections import Counter

# Dataset con 20 compañeros requeridos por la guía
estudiantes = [
    {"nombres": "Madison Odalis", "apellidos": "Valle Juárez", "edad": 20, "traslado": 30, "telefono": 8.5, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 9.0}},
    {"nombres": "Karen Elizabeth", "apellidos": "Ulloa Goméz", "edad": 18, "traslado": 40, "telefono": 9.0, "materias": {"Programación III": 10.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Flor Zulema", "apellidos": "Campos Orellana", "edad": 20, "traslado": 6, "telefono": 5.38, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Jimmy Arturo", "apellidos": "Marroquin Guzmán", "edad": 20, "traslado": 30, "telefono": 6.5, "materias": {"Programación III": 8.0, "Base de Datos II": 8.0, "Inglés Básico": 8.0, "Diseño de Circuitos Digitales": 8.0, "Estadística Computacional": 8.0}},
    {"nombres": "Diego Misael", "apellidos": "Villafranco Pineda", "edad": 20, "traslado": 30, "telefono": 8.0, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Yeimy Julissa", "apellidos": "Parada Chávez", "edad": 20, "traslado": 45, "telefono": 3.0, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Miguel Alejandro", "apellidos": "Gómez Saravia", "edad": 19, "traslado": 15, "telefono": 4.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Josué Stiven", "apellidos": "Funes Benavides", "edad": 19, "traslado": 30, "telefono": 5.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Jefferson Stiven", "apellidos": "Castillo Leiva", "edad": 19, "traslado": 15, "telefono": 2.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Ramael Ernesto", "apellidos": "Cordova Colindres", "edad": 22, "traslado": 7, "telefono": 13.52, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Carlos Daniel", "apellidos": "Parada Avalos", "edad": 25, "traslado": 10, "telefono": 5.52, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Carlos David", "apellidos": "Turcios Rivas", "edad": 20, "traslado": 25, "telefono": 5.0, "materias": {"Programación III": 9.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Gilda Mileidy", "apellidos": "González Castro", "edad": 19, "traslado": 30, "telefono": 5.92, "materias": {"Programación III": 10.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Samuel Alexander", "apellidos": "Portillo Cerón", "edad": 20, "traslado": 80, "telefono": 6.0, "materias": {"Programación III": 10.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Saúl Alexander", "apellidos": "Jimenez Garcia", "edad": 21, "traslado": 60, "telefono": 5.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Edgar Ernesto", "apellidos": "Ramirez Barrera", "edad": 21, "traslado": 60, "telefono": 7.0, "materias": {"Programación III": 9.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Jose Luis", "apellidos": "Garcia Mejia", "edad": 20, "traslado": 90, "telefono": 8.0, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 8.0, "Estadística Computacional": 8.0}},
    {"nombres": "Jaime Shafik", "apellidos": "Salmeron Chicas", "edad": 20, "traslado": 7, "telefono": 6.0, "materias": {"Programación III": 8.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 8.0}},
    {"nombres": "Wilfredo Josue", "apellidos": "Ortez Gaitan", "edad": 20, "traslado": 30, "telefono": 5.0, "materias": {"Programación III": 9.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 8.0}},
    {"nombres": "Andrea María", "apellidos": "López Rivas", "edad": 19, "traslado": 20, "telefono": 4.5, "materias": {"Programación III": 9.5, "Base de Datos II": 9.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.5}}
]

class EstadisticaEstudiantil:
    def __init__(self, datos):
        self.datos = datos

    def media(self, lista):
        return sum(lista) / len(lista)

    def mediana(self, lista):
        ordenados = sorted(lista)
        n = len(lista)
        mitad = n // 2
        return (ordenados[mitad - 1] + ordenados[mitad]) / 2 if n % 2 == 0 else ordenados[mitad]

    def moda(self, lista):
        conteo = Counter(lista)
        max_veces = max(conteo.values())
        if max_veces == 1:
            return "No hay moda"
        return [f"{num} (se repite {veces} veces)" for num, veces in conteo.items() if veces == max_veces]

    def varianza(self, lista):
        m = self.media(lista)
        return sum((x - m) ** 2 for x in lista) / (len(lista) - 1)

    def desviacion_estandar(self, lista):
        return math.sqrt(self.varianza(lista))

    def desviacion_tipica(self, lista):
        return self.desviacion_estandar(lista)

    def rango(self, lista):
        return max(lista) - min(lista)

    def frecuencia(self, lista):
        return dict(Counter(lista))

    def obtener_valores_y_mostrar(self, campo):
        valores = []
        print("\n--- DATOS ANALIZADOS ---")
        if campo == "nota":
            for est in self.datos:
                promedio = sum(est["materias"].values()) / len(est["materias"])
                valores.append(promedio)
                print(f"{est['nombres']} {est['apellidos']} -> Promedio General: {promedio:.2f} pts")
        elif campo == "traslado":
            for est in self.datos:
                val = est[campo]
                valores.append(val)
                print(f"{est['nombres']} {est['apellidos']} -> Traslado: {val} min")
        elif campo == "telefono":
            for est in self.datos:
                val = est[campo]
                valores.append(val)
                print(f"{est['nombres']} {est['apellidos']} -> Teléfono: {val} hrs")
        elif campo == "edad":
            for est in self.datos:
                val = est[campo]
                valores.append(val)
                print(f"{est['nombres']} {est['apellidos']} -> Edad: {val} años")
        return valores

    def elegir_campo(self):
        print("\n¿De cuál dato quieres calcular la estadística?")
        print("1. Notas (Promedio de materias)")
        print("2. Edades")
        print("3. Tiempo de traslado (minutos)")
        print("4. Horas de uso de teléfono")
        op = input("Elige una opción: ")
        opciones = {"1": "nota", "2": "edad", "3": "traslado", "4": "telefono"}
        return opciones.get(op, None)

    def ejecutar_menu(self):
        while True:
            print("\n==================================")
            print("   SISTEMA ESTADÍSTICO ACADÉMICO  ")
            print("==================================")
            print("1. Media aritmética")
            print("2. Mediana")
            print("3. Moda")
            print("4. Varianza")
            print("5. Desviación estándar")
            print("6. Desviación típica")
            print("7. Rango")
            print("8. Frecuencia")
            print("9. Ver explicación teórica (Diferencias)")
            print("0. Salir")

            opcion = input("Elige una opción: ")

            if opcion == "0":
                print("¡Hasta luego!")
                break
            elif opcion == "9":
                self.mostrar_explicacion_teorica()
                input("\nPresione Enter para volver al menú...")
                continue

            if opcion in [str(i) for i in range(1, 9)]:
                campo = self.elegir_campo()
                if campo is None:
                    print("Opción de campo no válida.")
                    continue

                valores = self.obtener_valores_y_mostrar(campo)

                print("\n==================================")
                print("       RESULTADO ESTADÍSTICO      ")
                print("==================================")
                if opcion == "1":
                    print(f"Media: {self.media(valores):.2f}")
                elif opcion == "2":
                    print(f"Mediana: {self.mediana(valores):.2f}")
                elif opcion == "3":
                    print(f"Moda: {self.moda(valores)}")
                elif opcion == "4":
                    print(f"Varianza: {self.varianza(valores):.2f}")
                elif opcion == "5":
                    print(f"Desviación estándar: {self.desviacion_estandar(valores):.2f}")
                elif opcion == "6":
                    print(f"Desviación típica: {self.desviacion_tipica(valores):.2f}")
                elif opcion == "7":
                    print(f"Rango: {self.rango(valores):.2f}")
                elif opcion == "8":
                    print(f"Frecuencia: {self.frecuencia(valores)}")

                input("\nPresione Enter para volver al menú...")
            else:
                print("Opción no válida. Intente de nuevo.")

    def mostrar_explicacion_teorica(self):
        print("\n-----------------------------------------------------------")
        print(" DIFERENCIA ENTRE LAS MEDIDAS ESTADÍSTICAS ")
        print("-----------------------------------------------------------")
        print("Media aritmética: Es el promedio de todos los datos. Se suman")
        print("   todos y se divide entre la cantidad de datos.")
        print("\nMediana: Es el dato que queda en medio cuando ordenamos los")
        print("   datos de menor a mayor. Se diferencia de la media porque")
        print("   no se toman todos los valores para hacer un promedio.")
        print("\nModa: Es el dato que más se repite. A diferencia de la media")
        print("   y la mediana, aquí nos fijamos en las repeticiones.")
        print("\nVarianza: Nos ayuda a saber qué tan separados están los")
        print("   datos del promedio.")
        print("\nDesviación estándar: También nos dice qué tanto se alejan")
        print("   los datos del promedio, pero es más fácil de interpretar")
        print("   que la varianza.")
        print("\nDesviación típica: Es lo mismo que la desviación estándar,")
        print("   solo es otro nombre.")
        print("\nRango: Es la diferencia entre el dato mayor y el menor.")
        print("   Solo toma en cuenta esos dos valores.")
        print("\nFrecuencia: Nos dice cuántas veces se repite cada dato.")
        print("\nEn general: La media, mediana y moda sirven para conocer los")
        print("   datos principales de un grupo, pero cada una lo hace de")
        print("   diferente manera. La varianza y la desviación estándar")
        print("   muestran qué tan separados están los datos del promedio,")
        print("   mientras que el rango compara solamente el dato mayor con")
        print("   el menor. La frecuencia sirve para saber cuántas veces")
        print("   se repite un dato.")
        print("-----------------------------------------------------------\n")


if __name__ == "__main__":
    app = EstadisticaEstudiantil(estudiantes)
    app.ejecutar_menu()
# Out:
# ...
#    SISTEMA ESTADÍSTICO ACADÉMICO
# ...
# 1. Media aritmética
# 2. Mediana
# 3. Moda
# 4. Varianza
# 5. Desviación estándar
# 6. Desviación típica
# 7. Rango
# 8. Frecuencia
# 9. Ver explicación teórica (Diferencias)
# 0. Salir
# Elige una opción: 0
# ¡Hasta luego!
